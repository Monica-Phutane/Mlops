# %% [markdown]
# <a href="https://colab.research.google.com/github/Monica-Phutane/Mlops/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import LSTM,Dense,Dropout
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
from datetime import datetime  #import datetime
start_date="2020-01-01"
end_date_forecast="2025-07-24"
#datetime.now().strftime('%Y-%m-%d')
print(f"\nToday:{end_date_forecast}")

#1.download data
ticker="SBIN.NS"
data=yf.download(ticker,start=start_date,end=end_date_forecast)

if not data.empty:
    # Access the 'High' column using the MultiIndex
    d_high=data[('High', ticker)]

    length=len(data)
    print("\n===========================================================")
    print(f"company:{ticker}")
    print(f"length:{length}")
    print("\n==========================================================")
    print(d_high.tail(5))
else:
    print(f"Could not download data for {ticker} for the specified date range.")
# Out:
# Today:2025-07-24
# /tmp/ipython-input-13-3000253577.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download(ticker,start=start_date,end=end_date_forecast)
# [*********************100%***********************]  1 of 1 completed
# ===========================================================
# company:SBIN.NS
# length:1378
#
# ==========================================================
# Date
# 2025-07-17    842.500000
# 2025-07-18    832.650024
# 2025-07-21    827.349976
# 2025-07-22    828.049988
# 2025-07-23    825.200012
# Name: (High, SBIN.NS), dtype: float64

# %%
from statsmodels.tsa.seasonal import STL

#1. STL Decomposition
stl=STL(d_high,period=30)
result=stl.fit()
trend=result.trend
seasonal=result.seasonal
residl=result.resid      # optional

#2.sequence preparation function
def prepare_lstm_data(series,window_size):
  scaler=MinMaxScaler()
  scaled=scaler.fit_transform(series.values.reshape(-1,1))
  x,y=[],[]
  for i in range(len(scaled)-window_size):
    x.append(scaled[i:i+window_size])
    y.append(scaled[i+window_size])
  return np.array(x),np.array(y),scaler

window_size=10
x_trend,y_trend,scaler_trend=prepare_lstm_data(trend,window_size)
x_seasonal,y_seasonal,scaler_seasonal=prepare_lstm_data(seasonal,window_size)

#3.LSTM Builder
def build_and_train_lstm(x,y,epochs=100):
  model=Sequential([
      LSTM(50, return_sequences=False, input_shape=(x.shape[1],1)),
      Dense(1)
  ])
  model.compile(optimizer='adam',loss='mse')
  model.fit(x,y,epochs=epochs,batch_size=10,verbose=2)
  return model

#4.train models
model_trend=build_and_train_lstm(x_trend,y_trend)
model_seasonal=build_and_train_lstm(x_seasonal,y_seasonal)

#5.predictions & inverse scaling
y_pred_trend=model_trend.predict(x_trend)
y_pred_seasonal=model_seasonal.predict(x_seasonal)

trend_pred=scaler_trend.inverse_transform(y_pred_trend)
seasonal_pred=scaler_seasonal.inverse_transform(y_pred_seasonal)

#6.final forecast
final_pred=trend_pred.flatten()+seasonal_pred.flatten()
actual=d_high.values[window_size:]

#7.plot actual vs predicted
plt.figure(figsize=(10,5))
plt.plot(actual,label='Actual',color='blue')
plt.plot(final_pred,label='Predicted (Trend + Seasonal)', color='red')
plt.title("LSTM Forecast on STL Components")
plt.legend()
plt.grid(True)
plt.show()

#8.RMSE
rmse=np.sqrt(mean_squared_error(actual,final_pred))
print(f"final RMSE(reconstructed):{rmse:.4f}")

# forecast 1 step ahead for trend
last_trend_window = trend.values[-window_size:].reshape(1,window_size,1)
last_trend_scaled=scaler_trend.transform(last_trend_window.reshape(window_size,1)).reshape(1,window_size,1)
next_trend_scaled = model_trend.predict(last_trend_scaled)
next_trend = scaler_trend.inverse_transform(next_trend_scaled)[0][0]

# forecast 1-step ahead for seasonal
last_seasonal_window = seasonal.values[-window_size:].reshape(1,window_size,1)
last_seasonal_scaled=scaler_seasonal.transform(last_seasonal_window.reshape(window_size,1)).reshape(1,window_size,1)
next_seasonal_scaled = model_seasonal.predict(last_seasonal_scaled)
next_seasonal = scaler_seasonal.inverse_transform(next_seasonal_scaled)[0][0]

# final forecast
next_day_forecast_high_LSTM = next_trend + next_seasonal
print(f"forecast for next day(Trend + Seasonal):{next_day_forecast_high_LSTM:.4f}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 137/137 - 4s - 28ms/step - loss: 0.0175
# Epoch 2/100
# 137/137 - 1s - 9ms/step - loss: 1.9122e-04
# Epoch 3/100
# 137/137 - 1s - 6ms/step - loss: 1.3306e-04
# Epoch 4/100
# 137/137 - 2s - 13ms/step - loss: 1.2616e-04
# Epoch 5/100
# 137/137 - 1s - 10ms/step - loss: 1.2231e-04
# Epoch 6/100
# 137/137 - 1s - 7ms/step - loss: 1.1691e-04
# Epoch 7/100
# 137/137 - 1s - 6ms/step - loss: 1.2020e-04
# Epoch 8/100
# 137/137 - 1s - 6ms/step - loss: 1.2103e-04
# Epoch 9/100
# 137/137 - 1s - 7ms/step - loss: 1.2126e-04
# Epoch 10/100
# 137/137 - 1s - 9ms/step - loss: 1.3975e-04
# Epoch 11/100
# 137/137 - 1s - 9ms/step - loss: 1.1981e-04
# Epoch 12/100
# 137/137 - 1s - 9ms/step - loss: 1.2844e-04
# Epoch 13/100
# 137/137 - 1s - 7ms/step - loss: 1.2409e-04
# Epoch 14/100
# 137/137 - 1s - 9ms/step - loss: 1.4345e-04
# Epoch 15/100
# 137/137 - 1s - 7ms/step - loss: 1.1053e-04
# Epoch 16/100
# 137/137 - 1s - 10ms/step - loss: 1.1299e-04
# Epoch 17/100
# 137/137 - 1s - 10ms/step - loss: 1.0596e-04
# Epoch 18/100
# 137/137 - 1s - 8ms/step - loss: 1.0425e-04
# Epoch 19/100
# 137/137 - 1s - 8ms/step - loss: 1.1173e-04
# Epoch 20/100
# 137/137 - 1s - 9ms/step - loss: 9.3326e-05
# Epoch 21/100
# 137/137 - 1s - 6ms/step - loss: 9.8968e-05
# Epoch 22/100
# 137/137 - 1s - 9ms/step - loss: 8.6623e-05
# Epoch 23/100
# 137/137 - 1s - 9ms/step - loss: 9.3284e-05
# Epoch 24/100
# 137/137 - 1s - 6ms/step - loss: 7.8040e-05
# Epoch 25/100
# 137/137 - 1s - 6ms/step - loss: 9.8616e-05
# Epoch 26/100
# 137/137 - 1s - 7ms/step - loss: 8.7216e-05
# Epoch 27/100
# 137/137 - 1s - 10ms/step - loss: 6.7525e-05
# Epoch 28/100
# 137/137 - 1s - 11ms/step - loss: 6.6751e-05
# Epoch 29/100
# 137/137 - 2s - 16ms/step - loss: 7.6477e-05
# Epoch 30/100
# 137/137 - 1s - 9ms/step - loss: 7.5488e-05
# Epoch 31/100
# 137/137 - 1s - 7ms/step - loss: 5.2970e-05
# Epoch 32/100
# 137/137 - 1s - 9ms/step - loss: 6.9773e-05
# Epoch 33/100
# 137/137 - 1s - 9ms/step - loss: 5.4039e-05
# Epoch 34/100
# 137/137 - 1s - 7ms/step - loss: 6.5347e-05
# Epoch 35/100
# 137/137 - 1s - 7ms/step - loss: 5.0518e-05
# Epoch 36/100
# 137/137 - 1s - 7ms/step - loss: 3.4502e-05
# Epoch 37/100
# 137/137 - 1s - 9ms/step - loss: 2.9936e-05
# Epoch 38/100
# 137/137 - 1s - 10ms/step - loss: 3.2185e-05
# Epoch 39/100
# 137/137 - 1s - 10ms/step - loss: 2.9514e-05
# Epoch 40/100
# 137/137 - 1s - 9ms/step - loss: 3.2242e-05
# Epoch 41/100
# 137/137 - 1s - 7ms/step - loss: 1.8201e-05
# Epoch 42/100
# 137/137 - 1s - 7ms/step - loss: 2.6790e-05
# Epoch 43/100
# 137/137 - 1s - 7ms/step - loss: 3.5693e-05
# Epoch 44/100
# 137/137 - 1s - 9ms/step - loss: 2.1685e-05
# Epoch 45/100
# 137/137 - 1s - 9ms/step - loss: 1.6789e-05
# Epoch 46/100
# 137/137 - 1s - 7ms/step - loss: 1.8045e-05
# Epoch 47/100
# 137/137 - 1s - 9ms/step - loss: 2.3758e-05
# Epoch 48/100
# 137/137 - 1s - 10ms/step - loss: 4.9242e-05
# Epoch 49/100
# 137/137 - 1s - 10ms/step - loss: 1.3722e-05
# Epoch 50/100
# 137/137 - 1s - 11ms/step - loss: 1.1323e-05
# Epoch 51/100
# 137/137 - 1s - 10ms/step - loss: 7.3981e-06
# Epoch 52/100
# 137/137 - 2s - 15ms/step - loss: 7.5180e-06
# Epoch 53/100
# 137/137 - 1s - 7ms/step - loss: 1.1726e-05
# Epoch 54/100
# 137/137 - 1s - 9ms/step - loss: 7.9842e-06
# Epoch 55/100
# 137/137 - 1s - 9ms/step - loss: 1.3485e-05
# Epoch 56/100
# 137/137 - 1s - 9ms/step - loss: 8.6274e-06
# Epoch 57/100
# 137/137 - 1s - 7ms/step - loss: 7.4786e-06
# Epoch 58/100
# 137/137 - 1s - 7ms/step - loss: 6.0498e-06
# Epoch 59/100
# 137/137 - 1s - 6ms/step - loss: 3.8573e-06
# Epoch 60/100
# 137/137 - 1s - 8ms/step - loss: 8.4109e-06
# Epoch 61/100
# 137/137 - 1s - 10ms/step - loss: 1.2713e-05
# Epoch 62/100
# 137/137 - 1s - 10ms/step - loss: 4.0445e-06
# Epoch 63/100
# 137/137 - 2s - 15ms/step - loss: 8.8198e-06
# Epoch 64/100
# 137/137 - 1s - 9ms/step - loss: 5.1324e-06
# Epoch 65/100
# 137/137 - 1s - 9ms/step - loss: 7.5945e-06
# Epoch 66/100
# 137/137 - 1s - 9ms/step - loss: 4.1039e-06
# Epoch 67/100
# 137/137 - 1s - 9ms/step - loss: 4.7798e-06
# Epoch 68/100
# 137/137 - 1s - 9ms/step - loss: 4.1010e-06
# Epoch 69/100
# 137/137 - 1s - 6ms/step - loss: 5.5548e-06
# Epoch 70/100
# 137/137 - 1s - 11ms/step - loss: 7.1533e-06
# Epoch 71/100
# 137/137 - 1s - 10ms/step - loss: 4.3407e-06
# Epoch 72/100
# 137/137 - 2s - 16ms/step - loss: 3.5889e-06
# Epoch 73/100
# 137/137 - 1s - 6ms/step - loss: 3.8960e-06
# Epoch 74/100
# 137/137 - 1s - 7ms/step - loss: 3.8575e-06
# Epoch 75/100
# 137/137 - 1s - 9ms/step - loss: 3.8717e-06
# Epoch 76/100
# 137/137 - 1s - 7ms/step - loss: 4.8129e-06
# Epoch 77/100
# 137/137 - 1s - 9ms/step - loss: 2.8927e-06
# Epoch 78/100
# 137/137 - 1s - 9ms/step - loss: 3.5406e-06
# Epoch 79/100
# 137/137 - 1s - 7ms/step - loss: 5.5182e-06
# Epoch 80/100
# 137/137 - 1s - 9ms/step - loss: 3.5730e-06
# Epoch 81/100
# 137/137 - 2s - 12ms/step - loss: 4.5770e-06
# Epoch 82/100
# 137/137 - 2s - 16ms/step - loss: 4.3085e-06
# Epoch 83/100
# 137/137 - 1s - 7ms/step - loss: 4.2920e-06
# Epoch 84/100
# 137/137 - 1s - 9ms/step - loss: 3.7997e-06
# Epoch 85/100
# 137/137 - 1s - 9ms/step - loss: 6.9332e-06
# Epoch 86/100
# 137/137 - 1s - 9ms/step - loss: 2.2867e-06
# Epoch 87/100
# 137/137 - 1s - 7ms/step - loss: 3.3895e-06
# Epoch 88/100
# 137/137 - 1s - 9ms/step - loss: 2.7904e-06
# Epoch 89/100
# 137/137 - 1s - 9ms/step - loss: 2.4020e-06
# Epoch 90/100
# 137/137 - 2s - 11ms/step - loss: 2.8115e-06
# Epoch 91/100
# 137/137 - 1s - 10ms/step - loss: 7.3999e-06
# Epoch 92/100
# 137/137 - 1s - 10ms/step - loss: 4.3033e-06
# Epoch 93/100
# 137/137 - 2s - 15ms/step - loss: 4.1412e-06
# Epoch 94/100
# 137/137 - 1s - 10ms/step - loss: 5.1279e-06
# Epoch 95/100
# 137/137 - 1s - 7ms/step - loss: 7.1841e-06
# Epoch 96/100
# 137/137 - 1s - 9ms/step - loss: 4.7883e-06
# Epoch 97/100
# 137/137 - 1s - 9ms/step - loss: 1.7261e-06
# Epoch 98/100
# 137/137 - 1s - 7ms/step - loss: 2.5519e-06
# Epoch 99/100
# 137/137 - 1s - 7ms/step - loss: 1.5904e-06
# Epoch 100/100
# 137/137 - 1s - 9ms/step - loss: 4.1490e-06
# Epoch 1/100
# 137/137 - 5s - 34ms/step - loss: 0.0232
# Epoch 2/100
# 137/137 - 1s - 7ms/step - loss: 0.0122
# Epoch 3/100
# 137/137 - 1s - 9ms/step - loss: 0.0090
# Epoch 4/100
# 137/137 - 1s - 7ms/step - loss: 0.0084
# Epoch 5/100
# 137/137 - 1s - 9ms/step - loss: 0.0083
# Epoch 6/100
# 137/137 - 1s - 9ms/step - loss: 0.0077
# Epoch 7/100
# 137/137 - 1s - 9ms/step - loss: 0.0073
# Epoch 8/100
# 137/137 - 1s - 7ms/step - loss: 0.0071
# Epoch 9/100
# 137/137 - 1s - 7ms/step - loss: 0.0071
# Epoch 10/100
# 137/137 - 1s - 10ms/step - loss: 0.0069
# Epoch 11/100
# 137/137 - 2s - 16ms/step - loss: 0.0068
# Epoch 12/100
# 137/137 - 1s - 9ms/step - loss: 0.0066
# Epoch 13/100
# 137/137 - 1s - 9ms/step - loss: 0.0065
# Epoch 14/100
# 137/137 - 1s - 7ms/step - loss: 0.0064
# Epoch 15/100
# 137/137 - 1s - 7ms/step - loss: 0.0065
# Epoch 16/100
# 137/137 - 1s - 7ms/step - loss: 0.0064
# Epoch 17/100
# 137/137 - 1s - 7ms/step - loss: 0.0063
# Epoch 18/100
# 137/137 - 1s - 9ms/step - loss: 0.0063
# Epoch 19/100
# 137/137 - 1s - 7ms/step - loss: 0.0061
# Epoch 20/100
# 137/137 - 1s - 8ms/step - loss: 0.0061
# Epoch 21/100
# 137/137 - 2s - 11ms/step - loss: 0.0061
# Epoch 22/100
# 137/137 - 1s - 10ms/step - loss: 0.0061
# Epoch 23/100
# 137/137 - 2s - 15ms/step - loss: 0.0062
# Epoch 24/100
# 137/137 - 1s - 9ms/step - loss: 0.0060
# Epoch 25/100
# 137/137 - 1s - 9ms/step - loss: 0.0060
# Epoch 26/100
# 137/137 - 1s - 9ms/step - loss: 0.0061
# Epoch 27/100
# 137/137 - 1s - 9ms/step - loss: 0.0062
# Epoch 28/100
# 137/137 - 1s - 7ms/step - loss: 0.0061
# Epoch 29/100
# 137/137 - 1s - 9ms/step - loss: 0.0062
# Epoch 30/100
# 137/137 - 2s - 12ms/step - loss: 0.0061
# Epoch 31/100
# 137/137 - 1s - 10ms/step - loss: 0.0060
# Epoch 32/100
# 137/137 - 1s - 10ms/step - loss: 0.0060
# Epoch 33/100
# 137/137 - 2s - 16ms/step - loss: 0.0060
# Epoch 34/100
# 137/137 - 1s - 7ms/step - loss: 0.0061
# Epoch 35/100
# 137/137 - 1s - 7ms/step - loss: 0.0060
# Epoch 36/100
# 137/137 - 1s - 9ms/step - loss: 0.0060
# Epoch 37/100
# 137/137 - 1s - 7ms/step - loss: 0.0059
# Epoch 38/100
# 137/137 - 1s - 9ms/step - loss: 0.0059
# Epoch 39/100
# 137/137 - 1s - 7ms/step - loss: 0.0060
# Epoch 40/100
# 137/137 - 1s - 9ms/step - loss: 0.0059
# Epoch 41/100
# 137/137 - 1s - 9ms/step - loss: 0.0059
# Epoch 42/100
# 137/137 - 1s - 10ms/step - loss: 0.0060
# Epoch 43/100
# 137/137 - 2s - 16ms/step - loss: 0.0060
# Epoch 44/100
# 137/137 - 1s - 9ms/step - loss: 0.0058
# Epoch 45/100
# 137/137 - 1s - 9ms/step - loss: 0.0059
# Epoch 46/100
# 137/137 - 1s - 7ms/step - loss: 0.0059
# Epoch 47/100
# 137/137 - 1s - 9ms/step - loss: 0.0058
# Epoch 48/100
# 137/137 - 1s - 9ms/step - loss: 0.0059
# Epoch 49/100
# 137/137 - 1s - 6ms/step - loss: 0.0058
# Epoch 50/100
# 137/137 - 1s - 7ms/step - loss: 0.0058
# Epoch 51/100
# 137/137 - 1s - 7ms/step - loss: 0.0059
# Epoch 52/100
# 137/137 - 1s - 10ms/step - loss: 0.0058
# Epoch 53/100
# 137/137 - 2s - 16ms/step - loss: 0.0058
# Epoch 54/100
# 137/137 - 1s - 7ms/step - loss: 0.0057
# Epoch 55/100
# 137/137 - 1s - 7ms/step - loss: 0.0058
# Epoch 56/100
# 137/137 - 1s - 6ms/step - loss: 0.0058
# Epoch 57/100
# 137/137 - 1s - 9ms/step - loss: 0.0057
# Epoch 58/100
# 137/137 - 1s - 9ms/step - loss: 0.0057
# Epoch 59/100
# 137/137 - 1s - 9ms/step - loss: 0.0058
# Epoch 60/100
# 137/137 - 1s - 7ms/step - loss: 0.0057
# Epoch 61/100
# 137/137 - 1s - 7ms/step - loss: 0.0057
# Epoch 62/100
# 137/137 - 1s - 8ms/step - loss: 0.0056
# Epoch 63/100
# 137/137 - 1s - 10ms/step - loss: 0.0056
# Epoch 64/100
# 137/137 - 2s - 16ms/step - loss: 0.0056
# Epoch 65/100
# 137/137 - 1s - 7ms/step - loss: 0.0057
# Epoch 66/100
# 137/137 - 1s - 9ms/step - loss: 0.0057
# Epoch 67/100
# 137/137 - 1s - 7ms/step - loss: 0.0056
# Epoch 68/100
# 137/137 - 1s - 7ms/step - loss: 0.0055
# Epoch 69/100
# 137/137 - 1s - 7ms/step - loss: 0.0055
# Epoch 70/100
# 137/137 - 1s - 9ms/step - loss: 0.0055
# Epoch 71/100
# 137/137 - 1s - 7ms/step - loss: 0.0057
# Epoch 72/100
# 137/137 - 1s - 9ms/step - loss: 0.0055
# Epoch 73/100
# 137/137 - 1s - 8ms/step - loss: 0.0055
# Epoch 74/100
# 137/137 - 1s - 10ms/step - loss: 0.0054
# Epoch 75/100
# 137/137 - 1s - 10ms/step - loss: 0.0055
# Epoch 76/100
# 137/137 - 2s - 15ms/step - loss: 0.0055
# Epoch 77/100
# 137/137 - 1s - 7ms/step - loss: 0.0054
# Epoch 78/100
# 137/137 - 1s - 9ms/step - loss: 0.0054
# Epoch 79/100
# 137/137 - 1s - 9ms/step - loss: 0.0054
# Epoch 80/100
# 137/137 - 1s - 9ms/step - loss: 0.0054
# Epoch 81/100
# 137/137 - 1s - 7ms/step - loss: 0.0053
# Epoch 82/100
# 137/137 - 1s - 9ms/step - loss: 0.0054
# Epoch 83/100
# 137/137 - 1s - 10ms/step - loss: 0.0054
# Epoch 84/100
# 137/137 - 1s - 10ms/step - loss: 0.0053
# Epoch 85/100
# 137/137 - 2s - 15ms/step - loss: 0.0054
# Epoch 86/100
# 137/137 - 1s - 7ms/step - loss: 0.0053
# Epoch 87/100
# 137/137 - 1s - 6ms/step - loss: 0.0053
# Epoch 88/100
# 137/137 - 1s - 9ms/step - loss: 0.0054
# Epoch 89/100
# 137/137 - 1s - 10ms/step - loss: 0.0052
# Epoch 90/100
# 137/137 - 1s - 9ms/step - loss: 0.0053
# Epoch 91/100
# 137/137 - 1s - 7ms/step - loss: 0.0052
# Epoch 92/100
# 137/137 - 1s - 7ms/step - loss: 0.0053
# Epoch 93/100
# 137/137 - 1s - 9ms/step - loss: 0.0053
# Epoch 94/100
# 137/137 - 2s - 12ms/step - loss: 0.0053
# Epoch 95/100
# 137/137 - 2s - 16ms/step - loss: 0.0053
# Epoch 96/100
# 137/137 - 1s - 7ms/step - loss: 0.0053
# Epoch 97/100
# 137/137 - 1s - 7ms/step - loss: 0.0052
# Epoch 98/100
# 137/137 - 1s - 9ms/step - loss: 0.0053
# Epoch 99/100
# 137/137 - 1s - 6ms/step - loss: 0.0053
# Epoch 100/100
# 137/137 - 1s - 9ms/step - loss: 0.0052
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# final RMSE(reconstructed):12.8878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# forecast for next day(Trend + Seasonal):815.5486
